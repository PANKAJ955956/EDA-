# %% [markdown]
# <a href="https://colab.research.google.com/github/PANKAJ955956/EDA-/blob/main/IPL%20WIN%20PREDICTION%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
match = pd.read_csv('matches.csv')
delivery = pd.read_csv('deliveries.csv')

# %%
match.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %%
match.shape
# Out:
# (1095, 20)

# %%
delivery.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum           0.0         1.0
# 1     2  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
# 2     3  BB McCullum  P Kumar   SC Ganguly           0.0         1.0
# 3     4  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
# 4     5  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0         1.0     legbyes        0.0              NaN            NaN     NaN
# 1         0.0         NaN        0.0              NaN            NaN     NaN
# 2         1.0       wides        0.0              NaN            NaN     NaN
# 3         0.0         NaN        0.0              NaN            NaN     NaN
# 4         0.0         NaN        0.0              NaN            NaN     NaN

# %%
delivery['match_id']
# Out:
# 0        335982
# 1        335982
# 2        335982
# 3        335982
# 4        335982
#           ...
# 40745    419162
# 40746    419162
# 40747    419162
# 40748    419162
# 40749    419162
# Name: match_id, Length: 40750, dtype: int64

# %%
delivery.shape
# Out:
# (40750, 17)

# %%
# Create a mapping from old match_id to new match_id
match_id_mapping = {old_id: new_id for new_id, old_id in enumerate(match['id'].unique(), start=1)}

# Replace match_id in both DataFrames
match['id'] = match['id'].map(match_id_mapping)
delivery['match_id'] = delivery['match_id'].map(match_id_mapping)

# %%
delivery['match_id']
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#         ...
# 40745    172
# 40746    172
# 40747    172
# 40748    172
# 40749    172
# Name: match_id, Length: 40750, dtype: int64

# %%
delivery.groupby(['match_id', 'inning']).sum()['total_runs']
# Out:
# match_id  inning
# 1         1         222.0
#           2          82.0
# 2         1         240.0
#           2         207.0
# 3         1         129.0
#                     ...
# 170       1         145.0
#           2         134.0
# 171       1         133.0
#           2         135.0
# 172       1         123.0
# Name: total_runs, Length: 347, dtype: float64

# %%
total_score_df = delivery.groupby(['match_id', 'inning']).sum()['total_runs'].reset_index()

# %%
total_score_df
# Out:
#      match_id  inning  total_runs
# 0           1       1       222.0
# 1           1       2        82.0
# 2           2       1       240.0
# 3           2       2       207.0
# 4           3       1       129.0
# ..        ...     ...         ...
# 342       170       1       145.0
# 343       170       2       134.0
# 344       171       1       133.0
# 345       171       2       135.0
# 346       172       1       123.0
#
# [347 rows x 3 columns]

# %%
# Now, we will consider only the first inning of each match.
total_score_df = total_score_df[total_score_df['inning'] == 1]

# %%
total_score_df
# Out:
#      match_id  inning  total_runs
# 0           1       1       222.0
# 2           2       1       240.0
# 4           3       1       129.0
# 6           4       1       165.0
# 8           5       1       110.0
# ..        ...     ...         ...
# 338       168       1       132.0
# 340       169       1       192.0
# 342       170       1       145.0
# 344       171       1       133.0
# 346       172       1       123.0
#
# [172 rows x 3 columns]

# %%
match_df = match.merge(total_score_df[['match_id', 'total_runs']], left_on = 'id', right_on = 'match_id')

# %%
match_df
# Out:
#       id   season        city        date  match_type player_of_match  \
# 0      1  2007/08   Bangalore  2008-04-18      League     BB McCullum
# 1      2  2007/08  Chandigarh  2008-04-19      League      MEK Hussey
# 2      3  2007/08       Delhi  2008-04-19      League     MF Maharoof
# 3      4  2007/08      Mumbai  2008-04-20      League      MV Boucher
# 4      5  2007/08     Kolkata  2008-04-20      League       DJ Hussey
# ..   ...      ...         ...         ...         ...             ...
# 167  168  2009/10     Kolkata  2010-04-17      League      JD Unadkat
# 168  169  2009/10  Dharamsala  2010-04-18      League        MS Dhoni
# 169  170  2009/10       Delhi  2010-04-18      League       A Symonds
# 170  171  2009/10     Kolkata  2010-04-19      League        M Kartik
# 171  172  2009/10      Mumbai  2010-04-21  Semi Final      KA Pollard
#
#                                             venue  \
# 0                           M Chinnaswamy Stadium
# 1      Punjab Cricket Association Stadium, Mohali
# 2                                Feroz Shah Kotla
# 3                                Wankhede Stadium
# 4                                    Eden Gardens
# ..                                            ...
# 167                                  Eden Gardens
# 168  Himachal Pradesh Cricket Association Stadium
# 169                              Feroz Shah Kotla
# 170                                  Eden Gardens
# 171                    Dr DY Patil Sports Academy
#
#                            team1                        team2  \
# 0    Royal Challengers Bangalore        Kolkata Knight Riders
# 1                Kings XI Punjab          Chennai Super Kings
# 2               Delhi Daredevils             Rajasthan Royals
# 3                 Mumbai Indians  Royal Challengers Bangalore
# 4          Kolkata Knight Riders              Deccan Chargers
# ..                           ...                          ...
# 167        Kolkata Knight Riders             Rajasthan Royals
# 168              Kings XI Punjab          Chennai Super Kings
# 169             Delhi Daredevils              Deccan Chargers
# 170        Kolkata Knight Riders               Mumbai Indians
# 171  Royal Challengers Bangalore               Mumbai Indians
#
#                      toss_winner  ...   result result_margin target_runs  \
# 0    Royal Challengers Bangalore  ...     runs         140.0       223.0
# 1            Chennai Super Kings  ...     runs          33.0       241.0
# 2               Rajasthan Royals  ...  wickets           9.0       130.0
# 3                 Mumbai Indians  ...  wickets           5.0       166.0
# 4                Deccan Chargers  ...  wickets           5.0       111.0
# ..                           ...  ...      ...           ...         ...
# 167             Rajasthan Royals  ...  wickets           8.0       133.0
# 168          Chennai Super Kings  ...  wickets           6.0       193.0
# 169              Deccan Chargers  ...     runs          11.0       146.0
# 170               Mumbai Indians  ...  wickets           9.0       134.0
# 171               Mumbai Indians  ...     runs          35.0       185.0
#
#      target_overs  super_over  method      umpire1         umpire2 match_id  \
# 0            20.0           N     NaN    Asad Rauf     RE Koertzen        1
# 1            20.0           N     NaN    MR Benson      SL Shastri        2
# 2            20.0           N     NaN    Aleem Dar  GA Pratapkumar        3
# 3            20.0           N     NaN     SJ Davis       DJ Harper        4
# 4            20.0           N     NaN    BF Bowden     K Hariharan        5
# ..            ...         ...     ...          ...             ...      ...
# 167          20.0           N     NaN   BG Jerling       RB Tiffin      168
# 168          20.0           N     NaN    BF Bowden       AM Saheba      169
# 169          20.0           N     NaN  BR Doctrove     SK Tarapore      170
# 170          20.0           N     NaN   BG Jerling     RE Koertzen      171
# 171          20.0           N     NaN  BR Doctrove       RB Tiffin      172
#
#     total_runs
# 0        222.0
# 1        240.0
# 2        129.0
# 3        165.0
# 4        110.0
# ..         ...
# 167      132.0
# 168      192.0
# 169      145.0
# 170      133.0
# 171      123.0
#
# [172 rows x 22 columns]

# %%
match_df.shape
# Out:
# (172, 22)

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings'],
#       dtype=object)

# %%
teams = [
    'Royal Challengers Bengaluru',
    'Mumbai Indians',
    'Kolkata Knight Riders',
    'Rajasthan Royals',
    'Chennai Super Kings',
    'Sunrisers Hyderabad',
    'Delhi Capitals',
    'Punjab Kings',
    'Lucknow Super Giants',
    'Gujarat Titans'
]

# %%
# Standardize team names in matches DataFrame (BEFORE filtering)
match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match_df['toss_winner'] = match_df['toss_winner'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match_df['winner'] = match_df['winner'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match_df['team1'] = match_df['team1'].str.replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru')
match_df['team2'] = match_df['team2'].str.replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru')
match_df['toss_winner'] = match_df['toss_winner'].str.replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru')
match_df['winner'] = match_df['winner'].str.replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru')  # Fix winner
match_df['team1'] = match_df['team1'].str.replace('Kings XI Punjab', 'Punjab Kings')
match_df['team2'] = match_df['team2'].str.replace('Kings XI Punjab', 'Punjab Kings')
match_df['toss_winner'] = match_df['toss_winner'].str.replace('Kings XI Punjab', 'Punjab Kings')
match_df['winner'] = match_df['winner'].str.replace('Kings XI Punjab', 'Punjab Kings')  # Fix winner
match_df['team1'] = match_df['team1'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
match_df['toss_winner'] = match_df['toss_winner'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
match_df['winner'] = match_df['winner'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')  # Fix winner

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bengaluru', 'Punjab Kings', 'Delhi Capitals',
#        'Mumbai Indians', 'Kolkata Knight Riders', 'Rajasthan Royals',
#        'Sunrisers Hyderabad', 'Chennai Super Kings'], dtype=object)

# %%
match_df['team2'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Royal Challengers Bengaluru', 'Sunrisers Hyderabad',
#        'Punjab Kings', 'Delhi Capitals', 'Mumbai Indians'], dtype=object)

# %%
match_df.shape
# Out:
# (172, 22)

# %%
# Duckworth-Lewis-Stern (DLS) method
match_df['method'].value_counts()
# Out:
# method
# D/L    5
# Name: count, dtype: int64

# %%
# DLS-affected matches

match_df[match_df['method'] == 'D/L'][['team1', 'team2', 'toss_winner', 'method']]
# Out:
#                     team1                  team2            toss_winner method
# 38         Delhi Capitals           Punjab Kings         Delhi Capitals    D/L
# 41  Kolkata Knight Riders    Chennai Super Kings  Kolkata Knight Riders    D/L
# 60         Delhi Capitals           Punjab Kings         Delhi Capitals    D/L
# 63           Punjab Kings  Kolkata Knight Riders  Kolkata Knight Riders    D/L
# 89    Chennai Super Kings           Punjab Kings    Chennai Super Kings    D/L

# %%
# Lets consider matches where (DLS) method was not applied

match_df = match_df[match_df['method'] != 'D/L']

# %%
match_df.columns.tolist()
# Out:
# ['id',
#  'season',
#  'city',
#  'date',
#  'match_type',
#  'player_of_match',
#  'venue',
#  'team1',
#  'team2',
#  'toss_winner',
#  'toss_decision',
#  'winner',
#  'result',
#  'result_margin',
#  'target_runs',
#  'target_overs',
#  'super_over',
#  'method',
#  'umpire1',
#  'umpire2',
#  'match_id',
#  'total_runs']

# %%
# extracting features from match dataset
match_df = match_df[['match_id','city','winner','total_runs','date']]
match_df.head()
# Out:
#    match_id        city                       winner  total_runs        date
# 0         1   Bangalore        Kolkata Knight Riders       222.0  2008-04-18
# 1         2  Chandigarh          Chennai Super Kings       240.0  2008-04-19
# 2         3       Delhi               Delhi Capitals       129.0  2008-04-19
# 3         4      Mumbai  Royal Challengers Bengaluru       165.0  2008-04-20
# 4         5     Kolkata        Kolkata Knight Riders       110.0  2008-04-20

# %%
# Replace old team names with new ones in delivery_df
delivery['batting_team'] = delivery['batting_team'].str.replace('Delhi Daredevils', 'Delhi Capitals')
delivery['bowling_team'] = delivery['bowling_team'].str.replace('Delhi Daredevils', 'Delhi Capitals')

delivery['batting_team'] = delivery['batting_team'].str.replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru')
delivery['bowling_team'] = delivery['bowling_team'].str.replace('Royal Challengers Bangalore', 'Royal Challengers Bengaluru')

delivery['batting_team'] = delivery['batting_team'].str.replace('Kings XI Punjab', 'Punjab Kings')
delivery['bowling_team'] = delivery['bowling_team'].str.replace('Kings XI Punjab', 'Punjab Kings')

delivery['batting_team'] = delivery['batting_team'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
delivery['bowling_team'] = delivery['bowling_team'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')

# %%
delivery = delivery[delivery['batting_team'].isin(teams)]
delivery = delivery[delivery['bowling_team'].isin(teams)]

# %%
delivery.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0         1       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 1         1       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 2         1       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 3         1       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
# 4         1       1  Kolkata Knight Riders  Royal Challengers Bengaluru     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum           0.0         1.0
# 1     2  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
# 2     3  BB McCullum  P Kumar   SC Ganguly           0.0         1.0
# 3     4  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
# 4     5  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0         1.0     legbyes        0.0              NaN            NaN     NaN
# 1         0.0         NaN        0.0              NaN            NaN     NaN
# 2         1.0       wides        0.0              NaN            NaN     NaN
# 3         0.0         NaN        0.0              NaN            NaN     NaN
# 4         0.0         NaN        0.0              NaN            NaN     NaN

# %%
delivery_df = match_df.merge(delivery, on = 'match_id')

# %%
delivery_df = delivery_df[delivery_df['inning'] == 2]

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x        date  \
# 124         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 125         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 126         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 127         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 128         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
#
#      inning                 batting_team           bowling_team  over  ball  \
# 124       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     1
# 125       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     2
# 126       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     3
# 127       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     4
# 128       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     5
#
#      ...    bowler non_striker batsman_runs  extra_runs  total_runs_y  \
# 124  ...  AB Dinda    W Jaffer          1.0         0.0           1.0
# 125  ...  AB Dinda    R Dravid          0.0         1.0           1.0
# 126  ...  AB Dinda    R Dravid          0.0         0.0           0.0
# 127  ...  AB Dinda    R Dravid          1.0         0.0           1.0
# 128  ...  AB Dinda    W Jaffer          1.0         0.0           1.0
#
#      extras_type is_wicket  player_dismissed dismissal_kind fielder
# 124          NaN       0.0               NaN            NaN     NaN
# 125        wides       0.0               NaN            NaN     NaN
# 126          NaN       0.0               NaN            NaN     NaN
# 127          NaN       0.0               NaN            NaN     NaN
# 128          NaN       0.0               NaN            NaN     NaN
#
# [5 rows x 21 columns]

# %%
delivery_df.shape
# Out:
# (19237, 21)

# %%
delivery_df.loc[:, 'current_score'] = delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x        date  \
# 124         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 125         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 126         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 127         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 128         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
#
#      inning                 batting_team           bowling_team  over  ball  \
# 124       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     1
# 125       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     2
# 126       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     3
# 127       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     4
# 128       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     5
#
#      ... non_striker batsman_runs extra_runs  total_runs_y  extras_type  \
# 124  ...    W Jaffer          1.0        0.0           1.0          NaN
# 125  ...    R Dravid          0.0        1.0           1.0        wides
# 126  ...    R Dravid          0.0        0.0           0.0          NaN
# 127  ...    R Dravid          1.0        0.0           1.0          NaN
# 128  ...    W Jaffer          1.0        0.0           1.0          NaN
#
#      is_wicket player_dismissed  dismissal_kind fielder current_score
# 124        0.0              NaN             NaN     NaN           1.0
# 125        0.0              NaN             NaN     NaN           2.0
# 126        0.0              NaN             NaN     NaN           2.0
# 127        0.0              NaN             NaN     NaN           3.0
# 128        0.0              NaN             NaN     NaN           4.0
#
# [5 rows x 22 columns]

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x        date  \
# 124         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 125         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 126         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 127         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 128         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
#
#      inning                 batting_team           bowling_team  over  ball  \
# 124       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     1
# 125       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     2
# 126       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     3
# 127       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     4
# 128       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     5
#
#      ... non_striker batsman_runs extra_runs  total_runs_y  extras_type  \
# 124  ...    W Jaffer          1.0        0.0           1.0          NaN
# 125  ...    R Dravid          0.0        1.0           1.0        wides
# 126  ...    R Dravid          0.0        0.0           0.0          NaN
# 127  ...    R Dravid          1.0        0.0           1.0          NaN
# 128  ...    W Jaffer          1.0        0.0           1.0          NaN
#
#      is_wicket player_dismissed  dismissal_kind fielder current_score
# 124        0.0              NaN             NaN     NaN           1.0
# 125        0.0              NaN             NaN     NaN           2.0
# 126        0.0              NaN             NaN     NaN           2.0
# 127        0.0              NaN             NaN     NaN           3.0
# 128        0.0              NaN             NaN     NaN           4.0
#
# [5 rows x 22 columns]

# %%
# Now lets see how many balls left

delivery_df['balls_left'] = 120 - (delivery_df['over']*6 + delivery_df['ball'])

# %%
delivery_df
# Out:
#        match_id       city                 winner  total_runs_x        date  \
# 124           1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 125           1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 126           1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 127           1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 128           1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# ...         ...        ...                    ...           ...         ...
# 39832       171    Kolkata  Kolkata Knight Riders         133.0  2010-04-19
# 39833       171    Kolkata  Kolkata Knight Riders         133.0  2010-04-19
# 39834       171    Kolkata  Kolkata Knight Riders         133.0  2010-04-19
# 39835       171    Kolkata  Kolkata Knight Riders         133.0  2010-04-19
# 39836       171    Kolkata  Kolkata Knight Riders         133.0  2010-04-19
#
#        inning                 batting_team           bowling_team  over  ball  \
# 124         2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     1
# 125         2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     2
# 126         2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     3
# 127         2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     4
# 128         2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     5
# ...       ...                          ...                    ...   ...   ...
# 39832       2        Kolkata Knight Riders         Mumbai Indians    16     6
# 39833       2        Kolkata Knight Riders         Mumbai Indians    16     7
# 39834       2        Kolkata Knight Riders         Mumbai Indians    17     1
# 39835       2        Kolkata Knight Riders         Mumbai Indians    17     2
# 39836       2        Kolkata Knight Riders         Mumbai Indians    17     3
#
#        ... batsman_runs extra_runs total_runs_y  extras_type  is_wicket  \
# 124    ...          1.0        0.0          1.0          NaN        0.0
# 125    ...          0.0        1.0          1.0        wides        0.0
# 126    ...          0.0        0.0          0.0          NaN        0.0
# 127    ...          1.0        0.0          1.0          NaN        0.0
# 128    ...          1.0        0.0          1.0          NaN        0.0
# ...    ...          ...        ...          ...          ...        ...
# 39832  ...          1.0        0.0          1.0          NaN        0.0
# 39833  ...          2.0        0.0          2.0          NaN        0.0
# 39834  ...          1.0        0.0          1.0          NaN        0.0
# 39835  ...          1.0        0.0          1.0          NaN        0.0
# 39836  ...          4.0        0.0          4.0          NaN        0.0
#
#        player_dismissed dismissal_kind  fielder current_score balls_left
# 124                 NaN            NaN      NaN           1.0        119
# 125                 NaN            NaN      NaN           2.0        118
# 126                 NaN            NaN      NaN           2.0        117
# 127                 NaN            NaN      NaN           3.0        116
# 128                 NaN            NaN      NaN           4.0        115
# ...                 ...            ...      ...           ...        ...
# 39832               NaN            NaN      NaN         127.0         18
# 39833               NaN            NaN      NaN         129.0         17
# 39834               NaN            NaN      NaN         130.0         17
# 39835               NaN            NaN      NaN         131.0         16
# 39836               NaN            NaN      NaN         135.0         15
#
# [19237 rows x 23 columns]

# %%
# now lets see how many wickets are left
# If a player is out, it is recorded next to their name; otherwise, it is marked as NaN.
# We will fill nan with 0

delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna("0")

# Wherever there is a name, we will replace it with 1.

delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x: x if x == '0' else "1")

#Here,`x if x == 0` ensures that if the value is 0,it remains unchanged,and it replaces other values (names) with 1

delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')

# lets count how many wickets have been taken

wickets= delivery_df.groupby("match_id")['player_dismissed'].cumsum().values

# Lets see how many wickets are left

delivery_df['wickets_left'] = 10- wickets

# %%
delivery_df.head()
# Out:
#      match_id       city                 winner  total_runs_x        date  \
# 124         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 125         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 126         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 127         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 128         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
#
#      inning                 batting_team           bowling_team  over  ball  \
# 124       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     1
# 125       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     2
# 126       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     3
# 127       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     4
# 128       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     5
#
#      ... extra_runs total_runs_y extras_type  is_wicket  player_dismissed  \
# 124  ...        0.0          1.0         NaN        0.0                 0
# 125  ...        1.0          1.0       wides        0.0                 0
# 126  ...        0.0          0.0         NaN        0.0                 0
# 127  ...        0.0          1.0         NaN        0.0                 0
# 128  ...        0.0          1.0         NaN        0.0                 0
#
#      dismissal_kind fielder  current_score  balls_left wickets_left
# 124             NaN     NaN            1.0         119           10
# 125             NaN     NaN            2.0         118           10
# 126             NaN     NaN            2.0         117           10
# 127             NaN     NaN            3.0         116           10
# 128             NaN     NaN            4.0         115           10
#
# [5 rows x 24 columns]

# %%
delivery_df.tail()
# Out:
#        match_id     city                 winner  total_runs_x        date  \
# 39832       171  Kolkata  Kolkata Knight Riders         133.0  2010-04-19
# 39833       171  Kolkata  Kolkata Knight Riders         133.0  2010-04-19
# 39834       171  Kolkata  Kolkata Knight Riders         133.0  2010-04-19
# 39835       171  Kolkata  Kolkata Knight Riders         133.0  2010-04-19
# 39836       171  Kolkata  Kolkata Knight Riders         133.0  2010-04-19
#
#        inning           batting_team    bowling_team  over  ball  ...  \
# 39832       2  Kolkata Knight Riders  Mumbai Indians    16     6  ...
# 39833       2  Kolkata Knight Riders  Mumbai Indians    16     7  ...
# 39834       2  Kolkata Knight Riders  Mumbai Indians    17     1  ...
# 39835       2  Kolkata Knight Riders  Mumbai Indians    17     2  ...
# 39836       2  Kolkata Knight Riders  Mumbai Indians    17     3  ...
#
#       extra_runs total_runs_y extras_type  is_wicket  player_dismissed  \
# 39832        0.0          1.0         NaN        0.0                 0
# 39833        0.0          2.0         NaN        0.0                 0
# 39834        0.0          1.0         NaN        0.0                 0
# 39835        0.0          1.0         NaN        0.0                 0
# 39836        0.0          4.0         NaN        0.0                 0
#
#        dismissal_kind fielder  current_score  balls_left wickets_left
# 39832             NaN     NaN          127.0          18            9
# 39833             NaN     NaN          129.0          17            9
# 39834             NaN     NaN          130.0          17            9
# 39835             NaN     NaN          131.0          16            9
# 39836             NaN     NaN          135.0          15            9
#
# [5 rows x 24 columns]

# %%
# Current run rate (crr)= runs/overs
delivery_df.loc[:, 'crr'] = (delivery_df['current_score']*6)/(120 - delivery_df['balls_left'])

# %%
# If winner and batting team are same then result will be 1 esle 0
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result, axis = 1)

# %%
delivery_df
# Out:
#        match_id       city                 winner  total_runs_x        date  \
# 124           1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 125           1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 126           1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 127           1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 128           1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# ...         ...        ...                    ...           ...         ...
# 39832       171    Kolkata  Kolkata Knight Riders         133.0  2010-04-19
# 39833       171    Kolkata  Kolkata Knight Riders         133.0  2010-04-19
# 39834       171    Kolkata  Kolkata Knight Riders         133.0  2010-04-19
# 39835       171    Kolkata  Kolkata Knight Riders         133.0  2010-04-19
# 39836       171    Kolkata  Kolkata Knight Riders         133.0  2010-04-19
#
#        inning                 batting_team           bowling_team  over  ball  \
# 124         2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     1
# 125         2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     2
# 126         2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     3
# 127         2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     4
# 128         2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     5
# ...       ...                          ...                    ...   ...   ...
# 39832       2        Kolkata Knight Riders         Mumbai Indians    16     6
# 39833       2        Kolkata Knight Riders         Mumbai Indians    16     7
# 39834       2        Kolkata Knight Riders         Mumbai Indians    17     1
# 39835       2        Kolkata Knight Riders         Mumbai Indians    17     2
# 39836       2        Kolkata Knight Riders         Mumbai Indians    17     3
#
#        ... extras_type is_wicket player_dismissed  dismissal_kind  fielder  \
# 124    ...         NaN       0.0                0             NaN      NaN
# 125    ...       wides       0.0                0             NaN      NaN
# 126    ...         NaN       0.0                0             NaN      NaN
# 127    ...         NaN       0.0                0             NaN      NaN
# 128    ...         NaN       0.0                0             NaN      NaN
# ...    ...         ...       ...              ...             ...      ...
# 39832  ...         NaN       0.0                0             NaN      NaN
# 39833  ...         NaN       0.0                0             NaN      NaN
# 39834  ...         NaN       0.0                0             NaN      NaN
# 39835  ...         NaN       0.0                0             NaN      NaN
# 39836  ...         NaN       0.0                0             NaN      NaN
#
#        current_score balls_left  wickets_left       crr result
# 124              1.0        119            10  6.000000      0
# 125              2.0        118            10  6.000000      0
# 126              2.0        117            10  4.000000      0
# 127              3.0        116            10  4.500000      0
# 128              4.0        115            10  4.800000      0
# ...              ...        ...           ...       ...    ...
# 39832          127.0         18             9  7.470588      1
# 39833          129.0         17             9  7.514563      1
# 39834          130.0         17             9  7.572816      1
# 39835          131.0         16             9  7.557692      1
# 39836          135.0         15             9  7.714286      1
#
# [19237 rows x 26 columns]

# %%
delivery_df['result'].value_counts()
# Out:
# result
# 1    9950
# 0    9287
# Name: count, dtype: int64

# %%
delivery_df.to_csv("delivery_df.csv", index=False)

# %%
teams
# Out:
# ['Royal Challengers Bengaluru',
#  'Mumbai Indians',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals',
#  'Chennai Super Kings',
#  'Sunrisers Hyderabad',
#  'Delhi Capitals',
#  'Punjab Kings',
#  'Lucknow Super Giants',
#  'Gujarat Titans']

# %%
delivery_df['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala'],
#       dtype=object)

# %%
df = pd.read_csv('delivery_df.csv')

# %%
df.head()
# Out:
#    match_id       city                 winner  total_runs_x        date  \
# 0         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 1         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 2         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 3         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
# 4         1  Bangalore  Kolkata Knight Riders         222.0  2008-04-18
#
#    inning                 batting_team           bowling_team  over  ball  \
# 0       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     1
# 1       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     2
# 2       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     3
# 3       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     4
# 4       2  Royal Challengers Bengaluru  Kolkata Knight Riders     0     5
#
#    ... extras_type is_wicket player_dismissed  dismissal_kind  fielder  \
# 0  ...         NaN       0.0                0             NaN      NaN
# 1  ...       wides       0.0                0             NaN      NaN
# 2  ...         NaN       0.0                0             NaN      NaN
# 3  ...         NaN       0.0                0             NaN      NaN
# 4  ...         NaN       0.0                0             NaN      NaN
#
#    current_score balls_left  wickets_left  crr result
# 0            1.0        119            10  6.0      0
# 1            2.0        118            10  6.0      0
# 2            2.0        117            10  4.0      0
# 3            3.0        116            10  4.5      0
# 4            4.0        115            10  4.8      0
#
# [5 rows x 26 columns]
